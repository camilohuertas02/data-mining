# %% [markdown]
# ## Procesamiento de datos y  predicción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
data = datasets.load_iris()
type(data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df["especie"] = data.target
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
correlacion = df.corr()
correlacion
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# especie                     0.782561         -0.426658           0.949035
#
#                    petal width (cm)   especie
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# especie                    0.956547  1.000000

# %%
#fig, ax=plt.subplots()
#cax = ax.natshow(correlacion, cmap="coolwarm")




plt.figure(figsize=(8,6))
plt.imshow(correlacion,cmap='coolwarm', interpolation='none')
plt.colorbar()

##etiqueta de los ejes
plt.xticks(np.arange(len(correlacion.columns)),correlacion.columns, rotation=90)
plt.yticks(np.arange(len(correlacion.columns)),correlacion.columns)

for i in range(len(correlacion.columns)):
    for j in range(len(correlacion.columns)):
        plt.text(j,i,f"{correlacion.iloc[i,j]:.2f}",ha="center",va="center", color="white")

plt.title("Matriz de correlaciòn de variables")
plt.tight_layout()
plt.show()

# %%
plt.scatter(df["petal length (cm)"],df["petal width (cm)"])

#Graficamos una unica linea recta

#m=0.2

#x = np.linspace(0,8,100)
#y = m * x
#for i in range(1,3,1):
#    plt.plot(i*x,y, color = "r")


m = np.linspace(0.2,0.4,10)
for i in m:
    plt.plot(df["petal length (cm)"],i*df["petal length (cm)"], color = "r")


plt.title("Grafico de variables con alta correlación")
plt.xlabel("Longitud del petalo")
plt.ylabel("Ancho del petalo")

plt.show()

# %%
y_real = df["petal width (cm)"]
x = df["petal length (cm)"]

#def RMSE(x,y_real,m):
#    RMSE=[]
#    for i in m:
#        for dato in x:
#                y_pred=i*dato
#                RMSE.append()


#residuo=(y_real - y_predic)


# determinamos los valores y_real
def RMSE(x,y_real,m):
    y_real_list=[]
    y_pred_list=[]
    residuo_list=[]
    for i in range(149):
        y_real_list.append(y_real[i])
    
    # determinamos los valres y_pred
    
    for dato in x:
        y_pred = m * dato
        y_pred_list.append(y_pred)
    
    for i in range(149):
        residuo = y_real_list[i]-y_pred_list[i]
        residuo_list.append(residuo*residuo)
    
    for i in range(149):
        suma=0
        suma=suma+residuo_list[i]
    
    suma = suma / 150
    rmse = np.sqrt(suma)
    return rmse

# %%
RMSE_list=[]
m = np.linspace(0.2,0.4,10)

for i in m:
    dato=RMSE(x, y_real, i)
    RMSE_list.append(dato)

RMSE_list
# Out:
# [None, None, None, None, None, None, None, None, None, None]
