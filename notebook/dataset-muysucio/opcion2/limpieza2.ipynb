# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df_dataset = pd.read_csv('base-hogares-2022.csv', sep=';')

df_dataset
# Out:
# /tmp/ipykernel_31919/2479029882.py:5: DtypeWarning: Columns (276,499) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dataset = pd.read_csv('base-hogares-2022.csv', sep=';')
#        ID_PER   WPER  CANT_MIEMBROS_HOGAR  CANT_PERSONAS0A17  CLIMA_EDUCATIVO  \
# 0      336578    124                    1                  0                2
# 1      305909    781                    1                  0                3
# 2      358892  34193                    4                  1                2
# 3      342664    968                    1                  0                3
# 4      394688  11509                    2                  0                3
# ...       ...    ...                  ...                ...              ...
# 12057  350535    825                    3                  0                1
# 12058  386729    504                    2                  0                1
# ...

# %%
df_dataset.isna().sum()
# Out:
# ID_PER                 0
# WPER                   0
# CANT_MIEMBROS_HOGAR    0
# CANT_PERSONAS0A17      0
# CLIMA_EDUCATIVO        0
#                       ..
# ID_06G                 0
# ID_06H                 0
# ID_06I                 0
# ID_07                  0
# ID_08,,,,,,,,,         0
# Length: 562, dtype: int64

# %%
df_dataset.shape
# Out:
# (12062, 562)
