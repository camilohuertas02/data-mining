# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df_dataset = pd.read_csv('base-estudio-hogares-2017.csv', sep=",")

df_dataset
# Out:
# /tmp/ipykernel_32612/537454034.py:5: DtypeWarning: Columns (72,114,293,304,306,460,463,465,472) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dataset = pd.read_csv('base-estudio-hogares-2017.csv', sep=",")
#           ID  REGION  Provincia  pondera_dem  tothogar  p1  p2  p3 p3.ot  \
# 0         37       2          2         2399         4   1   1   1
# 1         59       2          2         1986         2   1   1   1
# 2         64       2          2         1336         3   1   1   1
# 3        116       2          1         4706         3   1   1   4
# 4        121       2          1        11945         3   1   1   1
# ...      ...     ...        ...          ...       ...  ..  ..  ..   ...
# 20653   7862       4         22          202         2   2   3   1
# 20654  20249       4         22          147         2   1   3   1
# 20655   8443       4          3          144         6   1   3   1
# ...

# %%
df_dataset.isna().sum()
# Out:
# ID             0
# REGION         0
# Provincia      0
# pondera_dem    0
# tothogar       0
#               ..
# p193.d         0
# p193.e         0
# p193.f         0
# p193.g         0
# p193.h         0
# Length: 507, dtype: int64

# %%
df_dataset.shape
# Out:
# (20658, 507)
